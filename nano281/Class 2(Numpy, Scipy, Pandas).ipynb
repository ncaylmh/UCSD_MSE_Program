# %%
a = 1
b = 2.0
a + b
# Out:
# 3.0

# %%
s = "hello"

# %%
l =["a", 1, 2, "b"]

# %%
d = {"a": 1, "b": 2}

# %%
d["a"]
# Out:
# 1

# %%
l[0]
# Out:
# 'a'

# %%
l+l
# Out:
# ['a', 1, 2, 'b', 'a', 1, 2, 'b']

# %%
numpy ? # can not add a space between function and ?
# Out:
#   File "<ipython-input-9-20bf7dde582a>", line 1
#     numpy ?
#           ^
# SyntaxError: invalid syntax

# %%
np?

# %%
list().? #donot need to include the parenthesis, just name? is ok
# Out:
#   File "<ipython-input-46-8c4fd1b09b5c>", line 1
#     list().?
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Numpy exmples
# This is my example for numpy

# %% [markdown]
# I am going to interpret my result. and these are the insights.
# * insigh1
# * insight2

# %%
import numpy as np

# %%
# Create array

x = np.array([[1, 2, 3],
              [4, 7, 6],
              [9, 4, 2]])
y = np.array([1.5, 0.5, 3])
print(x)
print(y)
# Out:
# [[1 2 3]
#  [4 7 6]
#  [9 4 2]]
# [1.5 0.5 3. ]

# %%
x * x
# Out:
# array([[ 1,  4,  9],
#        [16, 49, 36],
#        [81, 16,  4]])

# %%
x + x
# Out:
# array([[ 2,  4,  6],
#        [ 8, 14, 12],
#        [18,  8,  4]])

# %% [markdown]
# ### Matrix dot

# %%
x .* x
# Out:
#   File "<ipython-input-22-992e6d93eeb6>", line 1
#     x .* x
#        ^
# SyntaxError: invalid syntax

# %%
np.dot(x,x)
# Out:
# array([[36, 28, 21],
#        [86, 81, 66],
#        [43, 54, 55]])

# %%
np.dot(x,y) # This gives x,y
# Out:
# array([11.5, 27.5, 21.5])

# %%
z = x.dot(y)
z = np.dot(x, y)

# %%
np.linalg.inv(x)
# Out:
# array([[ 0.16949153, -0.13559322,  0.15254237],
#        [-0.77966102,  0.42372881, -0.10169492],
#        [ 0.79661017, -0.23728814,  0.01694915]])

# %%
eigval, eigvec = np.linalg.eig(x)
print(eigval)
print(eigvec)
# Out:
# [12.50205135 -3.75787445  1.2558231 ]
# [[-0.27909662 -0.40149786  0.3019769 ]
#  [-0.79317124 -0.32770088 -0.78112084]
#  [-0.5412804   0.85522605  0.54649811]]

# %%
r = np. random.rand(10000,1)
print(r)
# Out:
# [[0.59369854]
#  [0.11962867]
#  [0.00090733]
#  ...
#  [0.1164842 ]
#  [0.16261943]
#  [0.32406475]]

# %%
# %time sum(i**2 for i in r)**0.5
# Out:
# CPU times: user 23.3 ms, sys: 1.33 ms, total: 24.7 ms
# Wall time: 24.9 ms
# array([57.78936267])

# %% [markdown]
# ## Magic function

# %% [markdown]
# ### 0. ? % !

# %% [markdown]
# #### 1. ?

# %%
np.dot?

# %%
np?

# %%
list()? #()no parentheses
# Out:
#   File "<ipython-input-55-769fd30a125e>", line 1
#     list()?
#           ^
# SyntaxError: invalid syntax

# %%
list?

# %% [markdown]
# #### 2.%

# %%
show the caculation time
# %time sum(i**2 for i in r)**0.5
# Out:
# CPU times: user 24.4 ms, sys: 1.61 ms, total: 26 ms
# Wall time: 28.9 ms
# array([57.78936267])

# %%
# %time np.sqrt(np.sum(r**2))
# Out:
# CPU times: user 597 µs, sys: 835 µs, total: 1.43 ms
# Wall time: 6.34 ms
# 57.78936267044139

# %% [markdown]
# ## Scipy

# %%
from scipy import stats # Statistic package

dist = stats.norm(0,1) # Gaussian distribution
dist.cdf(1.96) # cumulative distribution function for the value of 1.6
# Out:
# 0.9750021048517795

# %%
from scipy import constants # physical constant
constants.e
# Out:
# 1.602176634e-19

# %% [markdown]
# ## Pandas

# %% [markdown]
# Data analysis library \
# \
# Data structures deigned for working with relational or labeled data \
# \
# Twon main data types: \
#     **Series**: 1D labeled homogeneously-typed array \
#     **DataFrame**: 2D labeled, size-mutable tabular structure with potentially heterogeneously-typed column \
#     \
# It is helpful to think of DataFrame as essentially a python object representing the contents of a table, e.g. such as what you would have in Excel spreadsheet. This is similar to the dataframe in R.

# %% [markdown]
# For this demo, we will utilize data that has been published by the MAterials Simulation Toolkit - Machine Learning (MAST - ML) on figshare

# %%
from io import StringIO
import pandas as pd
import requests

#Get the raw text of the data directly from hte gifshare url.
url = "https://ndownloader.figshare.com/files/13007075"
raw = requests.get(url).text
raw
# Out:
# 'Material compositions 1,Material compositions 2,Enorm (eV),E_raw (eV),Site2_MeltingT,Site1_MendeleevNumber,Site1_MiracleRadius,GSestFCClatcnt_max_value,Site2_BCCenergy_pa,Site1_BCCfermi,CovalentRadius_max_value,Site2_Density,n_ws^third_min_value,Site1_HHIr,IonicRadii_max_value,BoilingT_max_value,valence_arithmetic_average,Site2_NdUnfilled,Site1_IonicRadii,BCCenergy_pa_composition_average,MiracleRadius_min_value,MeltingT_min_value,NUnfilled_max_value,Site2_Group,Site1_CovalentRadii,Site2_NUnfilled,SpecificHeatCapacity_difference,Site1_Electronegativity,BCCenergy_pa_arithmetic_average\r\nAg,Ag,0,1.82445,-0.531814423,0.402504212,0.26304467,-0.626924632,1.021336909,-1.217816005,-0.423908049,0.152291483,-0.193919721,-0.589845856,1.636880876,-1.432543479,-1.676965927,-0.943565335,3.316369481,1.386572578,0.859807591,-0.046109375,-1.546560596,0.626614816,0.690287126,-1.036320247,-1.05789813,0.099470946,1.386572578\r\nAg,Co,-0.090141676,1.734308324,0.064050614,0.402504212,0.26304467,-0.62692
# ...

# %%
# Then reads in the data as a pandas DataFrame (CSV?)
data = pd.read_csv(StringIO(raw))
data
print(data) #print(data) shows different with  data
# Out:
#     Material compositions 1 Material compositions 2  Enorm (eV)  E_raw (eV)  \
# 0                        Ag                      Ag    0.000000    1.824450
# 1                        Ag                      Co   -0.090142    1.734308
# 2                        Ag                      Cr    0.259139    2.083589
# 3                        Ag                      Cu   -0.022200    1.802250
# 4                        Ag                      Fe    0.317672    2.142122
# ..                      ...                     ...         ...         ...
# 403                      Zr                      Nb   -0.067020    2.576100
# 404                      Zr                      Ta    0.153850    2.796970
# 405                      Zr                      Ti    0.248110    2.891230
# 406                      Zr                      Hf    0.204140    2.847260
# 407                      Zr                      Sn    0.248040    2.891160
#
# ...

# %%
#Extrating a colume as a series
form_e = data['E_raw (eV)']
form_e
# Out:
# 0      1.824450
# 1      1.734308
# 2      2.083589
# 3      1.802250
# 4      2.142122
#          ...
# 403    2.576100
# 404    2.796970
# 405    2.891230
# 406    2.847260
# 407    2.891160
# Name: E_raw (eV), Length: 408, dtype: float64

# %%
df = data[data["Enorm (eV)"] >= 0]
df
# Out:
#     Material compositions 1 Material compositions 2  Enorm (eV)  E_raw (eV)  \
# 0                        Ag                      Ag    0.000000    1.824450
# 2                        Ag                      Cr    0.259139    2.083589
# 4                        Ag                      Fe    0.317672    2.142122
# 5                        Ag                      Mn    0.202186    2.026636
# 6                        Ag                      Ni    0.250571    2.075021
# ..                      ...                     ...         ...         ...
# 402                      Zr                      Ag    0.129350    2.772470
# 404                      Zr                      Ta    0.153850    2.796970
# 405                      Zr                      Ti    0.248110    2.891230
# 406                      Zr                      Hf    0.204140    2.847260
# 407                      Zr                      Sn    0.248040    2.891160
#
# ...

# %%
#Summary statistics
data.describe()
# Out:
#        Enorm (eV)  E_raw (eV)  Site2_MeltingT  Site1_MendeleevNumber  \
# count  408.000000  408.000000    4.080000e+02           4.080000e+02
# mean     0.094921    2.811950   -9.803927e-12           7.598037e-11
# std      0.473858    1.333060    1.001228e+00           1.001228e+00
# min     -0.939330    0.777611   -1.650295e+00          -5.157834e+00
# 25%     -0.189815    1.919531   -8.687861e-01          -5.561748e-01
# 50%     -0.056590    2.543001    6.516841e-02           1.149005e-01
# 75%      0.257167    3.161065    5.882983e-01           6.901079e-01
# max      1.936200    6.069955    2.218049e+00           1.936391e+00
#
#        Site1_MiracleRadius  GSestFCClatcnt_max_value  Site2_BCCenergy_pa  \
# count         4.080000e+02              4.080000e+02        4.080000e+02
# mean          3.483053e-17              2.450972e-12        3.186274e-11
# std           1.001228e+00              1.001228e+00        1.001228e+00
# ...

# %%
df.plot(x="Enorm (eV)", y = "E_raw (eV)", kind ="scatter")

# %% [markdown]
# ## Scikit-learn & TensorFlow
#
# * packages for machine learning.
# * To some extent, they are overlap in functionality.
# Instead, we will provide an overview of the high-;eve; APL deign of scikit-learn
# \
# ### Scikit-learning Model API
# All ML models inherrit from BaseEstimator and Various mix-in classes with standardized method names

# %%
model = Model(**params) # Init a model with parameters.
model.get_params() # Get model parameters.
model.set_params(**params) # Set model parameters
model.fit(X,y) # Fit the model with a dataset
model.score(X,y) # Provides the score for the dataset.
model.predict(X) # Make a prediction using filted model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-f0d294f7d258> in <module>
# ----> 1 model = Model(**params) # Init a model with parameters.
#       2 model.get_params() # Get model parameters.
#       3 Model.set_params(**params) # Set model parameters
#
# NameError: name 'Model' is not defined

# %% [markdown]
# ## Matplotlib and Seaborn
#
# * Plotting libraries
# * Matplotlib is the de facto library for generating all kinds of plots and many other plotting engines (including seaborn) are build on top of it
# * seanborn is a extemly helpful package for staticstical data visualization. Works very well with Pandas DataFrame

# %%
import matplotlib.pyplot as plt
# Plot two variables x and y with 'x' as markers and solidlines.
plt.plot(x,y, 'x-')
#using circles as markers and dased lines instead
plt.plot(x,y, 'o--')

# %%
import seaborn as sns
# Plot the distribution of x.
sns.distplot(data["Enorm (eV)"])
# Scatter plot using columes from DataFrame
sns.scatterplot(x="Melting point", y="Modulus", data = materials)
# Out:
# /opt/anaconda3/envs/nano281/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-1e0e6cfe60f4> in <module>
#       3 sns.distplot(data["Enorm (eV)"])
#       4 # Scatter plot using columes from DataFrame
# ----> 5 sns.scatterplot(x="Melting point", y="Modulus", data = materials)
#
# NameError: name 'materials' is not defined

# %% [markdown]
# **Seaborn gallery** contains may visual example with source code
